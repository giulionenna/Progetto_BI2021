# %%
import pandas as pd

data = pd.read_excel(r'data_dec.xlsx')
df=pd.DataFrame(data)

# %%
df['created_at_DATE'] = df.created_at_ntz.dt.date

# %%
df.to_excel('data_exploration.xlsx')

# %%
df.loc[df['unsure_wrong_detection']==True].shape
# Out:
# (34, 12)

# %%
from matplotlib import pyplot as plt

plt.hist(df.favorite_count,  log=True, rwidth=0.8)
# Out:
# (array([4.165e+03, 0.000e+00, 2.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([    0. ,  2380.5,  4761. ,  7141.5,  9522. , 11902.5, 14283. ,
#         16663.5, 19044. , 21424.5, 23805. ]),
#  <BarContainer object of 10 artists>)
